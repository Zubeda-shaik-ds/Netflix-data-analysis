# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("netflix_titles.csv")

print(df.head())

# Movies vs TV Shows
type_count = df['type'].value_counts()
print(type_count)

type_count.plot(kind='bar')
plt.title("Movies vs TV Shows")
plt.show()

# Top countries
top_countries = df['country'].value_counts()
print(top_countries)

top_countries.plot(kind='bar')
plt.title("Content by Country")
plt.show()

# Release trend
df['release_year'].value_counts().sort_index().plot()
plt.title("Release Year Trend")
plt.show()
# Out:
#   show_id     type            title        country  release_year
# 0      s1    Movie       Red Notice  United States          2021
# 1      s2  TV Show  Stranger Things  United States          2016
# 2      s3    Movie              RRR          India          2022
# 3      s4  TV Show     Sacred Games          India          2018
# 4      s5    Movie       Extraction  United States          2020
# type
# Movie      6
# TV Show    6
# Name: count, dtype: int64
# country
# United States    5
# India            5
# Spain            1
# Germany          1
# Name: count, dtype: int64
